# %%
# !python -V
# Out:
# Python 3.9.12

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.feature_extraction import DictVectorizer
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Lasso
from sklearn.linear_model import Ridge
from sklearn.metrics import mean_squared_error

# %%
import pickle

# %%
df = pd.read_parquet('https://d37ci6vzurychx.cloudfront.net/trip-data/green_tripdata_2024-01.parquet')
df.lpep_pickup_datetime = pd.to_datetime(df.lpep_pickup_datetime)
df.lpep_dropoff_datetime = pd.to_datetime(df.lpep_dropoff_datetime)

# %%
df
# Out:
#        VendorID lpep_pickup_datetime lpep_dropoff_datetime store_and_fwd_flag  \
# 0             2  2024-01-01 00:46:55   2024-01-01 00:58:25                  N
# 1             2  2024-01-01 00:31:42   2024-01-01 00:52:34                  N
# 2             2  2024-01-01 00:30:21   2024-01-01 00:49:23                  N
# 3             1  2024-01-01 00:30:20   2024-01-01 00:42:12                  N
# 4             2  2024-01-01 00:32:38   2024-01-01 00:43:37                  N
# ...         ...                  ...                   ...                ...
# 56546         2  2024-01-31 20:46:00   2024-01-31 20:55:00               None
# 56547         2  2024-01-31 21:06:00   2024-01-31 21:11:00               None
# 56548         2  2024-01-31 21:36:00   2024-01-31 21:40:00               None
# 56549         2  2024-01-31 22:45:00   2024-01-31 22:51:00               None
# 56550         2  2024-01-31 22:28:00   2024-01-31 22:59:00               None
#
# ...

# %%
df['duration']= df.lpep_dropoff_datetime - df.lpep_pickup_datetime
df.duration = df.duration.apply(lambda td: td.total_seconds()/60)

# %%
#df=df[df.trip_type==2]

# %%
df
# Out:
#        VendorID lpep_pickup_datetime lpep_dropoff_datetime store_and_fwd_flag  \
# 0             2  2024-01-01 00:46:55   2024-01-01 00:58:25                  N
# 1             2  2024-01-01 00:31:42   2024-01-01 00:52:34                  N
# 2             2  2024-01-01 00:30:21   2024-01-01 00:49:23                  N
# 3             1  2024-01-01 00:30:20   2024-01-01 00:42:12                  N
# 4             2  2024-01-01 00:32:38   2024-01-01 00:43:37                  N
# ...         ...                  ...                   ...                ...
# 56546         2  2024-01-31 20:46:00   2024-01-31 20:55:00               None
# 56547         2  2024-01-31 21:06:00   2024-01-31 21:11:00               None
# 56548         2  2024-01-31 21:36:00   2024-01-31 21:40:00               None
# 56549         2  2024-01-31 22:45:00   2024-01-31 22:51:00               None
# 56550         2  2024-01-31 22:28:00   2024-01-31 22:59:00               None
#
# ...

# %%
df.duration.describe(percentiles=[0.95,0.98,0.99])
# Out:
# count    56551.000000
# mean        18.171379
# std         75.464751
# min          0.000000
# 50%         11.400000
# 95%         33.683333
# 98%         46.816667
# 99%         59.825000
# max       1438.983333
# Name: duration, dtype: float64

# %%
df = df[(df.duration >= 1) & (df.duration <= 60)]

# %%
df
# Out:
#        VendorID lpep_pickup_datetime lpep_dropoff_datetime store_and_fwd_flag  \
# 0             2  2024-01-01 00:46:55   2024-01-01 00:58:25                  N
# 1             2  2024-01-01 00:31:42   2024-01-01 00:52:34                  N
# 2             2  2024-01-01 00:30:21   2024-01-01 00:49:23                  N
# 3             1  2024-01-01 00:30:20   2024-01-01 00:42:12                  N
# 4             2  2024-01-01 00:32:38   2024-01-01 00:43:37                  N
# ...         ...                  ...                   ...                ...
# 56546         2  2024-01-31 20:46:00   2024-01-31 20:55:00               None
# 56547         2  2024-01-31 21:06:00   2024-01-31 21:11:00               None
# 56548         2  2024-01-31 21:36:00   2024-01-31 21:40:00               None
# 56549         2  2024-01-31 22:45:00   2024-01-31 22:51:00               None
# 56550         2  2024-01-31 22:28:00   2024-01-31 22:59:00               None
#
# ...

# %%
categorical = ['PULocationID','DOLocationID']
numerical = ['trip_distance']

# %%
df[categorical] = df[categorical].astype(str)
# Out:
# /tmp/ipykernel_4751/1767203464.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[categorical] = df[categorical].astype(str)

# %%
df.dtypes
# Out:
# VendorID                          int32
# lpep_pickup_datetime     datetime64[ns]
# lpep_dropoff_datetime    datetime64[ns]
# store_and_fwd_flag               object
# RatecodeID                      float64
# PULocationID                     object
# DOLocationID                     object
# passenger_count                 float64
# trip_distance                   float64
# fare_amount                     float64
# extra                           float64
# mta_tax                         float64
# tip_amount                      float64
# tolls_amount                    float64
# ehail_fee                       float64
# improvement_surcharge           float64
# total_amount                    float64
# payment_type                    float64
# trip_type                       float64
# congestion_surcharge            float64
# duration                        float64
# dtype: object

# %%
df[categorical + numerical]
# Out:
#       PULocationID DOLocationID  trip_distance
# 0              236          239           1.98
# 1               65          170           6.54
# 2               74          262           3.08
# 3               74          116           2.40
# 4               74          243           5.14
# ...            ...          ...            ...
# 56546           33           25           0.00
# 56547           72           72           0.49
# 56548           72           72           0.52
# 56549           41           42           1.17
# 56550           33           91           9.27
#
# [54373 rows x 3 columns]

# %%
df[categorical + numerical].iloc[:10]
# Out:
#   PULocationID DOLocationID  trip_distance
# 0          236          239           1.98
# 1           65          170           6.54
# 2           74          262           3.08
# 3           74          116           2.40
# 4           74          243           5.14
# 5           33          209           2.00
# 6           74          238           3.20
# 7          166          239           2.01
# 8          226          226           0.31
# 9            7          129           2.32

# %%
train_dicts = df[categorical + numerical].iloc[:10].to_dict(orient = 'records')

# %%
#implementing it to the entire data set

# %%
train_dicts = df[categorical + numerical].to_dict(orient = 'records')

# %%
dv = DictVectorizer()
X_train = dv.fit_transform(train_dicts)

# %%
X_train
# Out:
# <54373x449 sparse matrix of type '<class 'numpy.float64'>'
# 	with 163119 stored elements in Compressed Sparse Row format>

# %%
dv.feature_names_
# Out:
# ['DOLocationID=1',
#  'DOLocationID=10',
#  'DOLocationID=100',
#  'DOLocationID=101',
#  'DOLocationID=102',
#  'DOLocationID=106',
#  'DOLocationID=107',
#  'DOLocationID=108',
#  'DOLocationID=11',
#  'DOLocationID=112',
#  'DOLocationID=113',
#  'DOLocationID=114',
#  'DOLocationID=116',
#  'DOLocationID=117',
#  'DOLocationID=118',
#  'DOLocationID=119',
#  'DOLocationID=12',
#  'DOLocationID=120',
#  'DOLocationID=121',
#  'DOLocationID=122',
#  'DOLocationID=123',
#  'DOLocationID=124',
#  'DOLocationID=125',
#  'DOLocationID=126',
#  'DOLocationID=127',
#  'DOLocationID=128',
#  'DOLocationID=129',
#  'DOLocationID=13',
#  'DOLocationID=130',
#  'DOLocationID=131',
#  'DOLocationID=132',
#  'DOLocationID=133',
#  'DOLocationID=134',
#  'DOLocationID=135',
#  'DOLocationID=136',
#  'DOLocationID=137',
#  'DOLocationID=138',
#  'DOLocationID=139',
#  'DOLocationID=14',
#  'DOLocationID=140',
#  'DOLocationID=141',
#  'DOLocationID=142',
#  'DOLocationID=143',
# ...

# %%
target = 'duration'
y_train = df[target].values

# %%
y_train
# Out:
# array([11.5       , 20.86666667, 19.03333333, ...,  4.        ,
#         6.        , 31.        ])

# %%
##Now lets train our model

# %%
lr = LinearRegression()
lr.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = lr.predict(X_train)

# %%
sns.distplot(y_pred, label = 'predictions')
sns.distplot(y_train, label = 'actual')
plt.legend()
# Out:
# /home/codespace/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /home/codespace/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
mean_squared_error(y_train,y_pred,squared=False)
# Out:
# 7.081905382194463

# %%
##putting the process of reading dataframe into single function

# %%
def read_dataframe(filename):
    df = pd.read_parquet(filename)
    
    df.lpep_pickup_datetime = pd.to_datetime(df.lpep_pickup_datetime)
    df.lpep_dropoff_datetime = pd.to_datetime(df.lpep_dropoff_datetime)
    
    df['duration']= df.lpep_dropoff_datetime - df.lpep_pickup_datetime
    df.duration = df.duration.apply(lambda td: td.total_seconds()/60)
    
    df = df[(df.duration >= 1) & (df.duration <= 60)]
    
    categorical = ['PULocationID','DOLocationID']
    
    df[categorical] = df[categorical].astype(str)
    
    return df

# %%
df_train = read_dataframe('https://d37ci6vzurychx.cloudfront.net/trip-data/green_tripdata_2024-01.parquet')

# %%
df_validation = read_dataframe('https://d37ci6vzurychx.cloudfront.net/trip-data/green_tripdata_2024-02.parquet')

# %%
len(df_train),len(df_validation)
# Out:
# (54373, 51497)

# %%
df_train['PU_DO']= df_train['PULocationID'] + '_' + df_train['DOLocationID']
df_validation['PU_DO']= df_validation['PULocationID'] + '_' + df_validation['DOLocationID']

# %%
df_validation
# Out:
#        VendorID lpep_pickup_datetime lpep_dropoff_datetime store_and_fwd_flag  \
# 0             2  2024-02-01 00:15:53   2024-02-01 00:24:20                  N
# 1             2  2024-01-31 22:59:22   2024-01-31 23:27:14                  N
# 2             2  2024-02-01 00:30:29   2024-02-01 00:35:32                  N
# 3             2  2024-01-31 23:56:42   2024-02-01 00:06:53                  N
# 5             2  2024-02-01 00:06:23   2024-02-01 00:10:10                  N
# ...         ...                  ...                   ...                ...
# 53572         2  2024-02-29 21:07:00   2024-02-29 21:34:00               None
# 53573         2  2024-02-29 22:35:38   2024-02-29 22:46:25               None
# 53574         2  2024-02-29 22:14:00   2024-02-29 22:39:00               None
# 53575         2  2024-02-29 22:41:00   2024-02-29 22:53:00               None
# 53576         2  2024-02-29 23:04:48   2024-02-29 23:19:05               None
#
# ...

# %%
##creating training pipeline

# %%
categorical = ['PU_DO']
numerical = ['trip_distance']


dv = DictVectorizer()

train_dicts = df_train[categorical + numerical].to_dict(orient = 'records')
X_train = dv.fit_transform(train_dicts)

validation_dicts = df_validation[categorical + numerical].to_dict(orient = 'records')
X_validation = dv.transform(validation_dicts)

# %%
target = 'duration'
y_train = df_train[target].values
y_validation = df_validation[target].values

# %%
#training
lr = LinearRegression()
lr.fit(X_train,y_train)

#prediction
y_pred = lr.predict(X_validation)

#evaluation
mean_squared_error(y_validation,y_pred,squared=False)
# Out:
# 5.982652114977233

# %%
#Now we have receieved 7.2 delay as average delay baseline, lets try lasso model

# %%
#training
ls = Lasso()
ls.fit(X_train,y_train)

#prediction
y_pred = ls.predict(X_validation)

#evaluation
mean_squared_error(y_validation,y_pred,squared=False)
# Out:
# 9.110340896856446

# %%
#The average delay increased, so its not a good model for us, lets try another model

# %%
#trying ridge model

# %%
#training
rd = Ridge()
rd.fit(X_train,y_train)

#prediction
y_pred = rd.predict(X_validation)

#evaluation
mean_squared_error(y_validation,y_pred,squared=False)
# Out:
# 8.036959496555712

# %%
#Saving the model

# %%
with open('models/linear_regression.bin','wb') as f_out:
    pickle.dump((dv,lr), f_out)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Input In [60], in <cell line: 1>()
# ----> 1 with open('models/linear_regression.bin','wb') as f_out:
#       2     pickle.dump((dv,lr), f_out)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'models/linear_regression.bin'
